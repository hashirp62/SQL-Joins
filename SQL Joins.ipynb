# %% [markdown]
# **customers**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Orders**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Payments**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **employees**
#
# ![image.png](data:image/png;base64,...)

# %%
Q1.

select o.customerID, c.customername,c.city
from orders o
left join customers c
on c.customerID = o.customerID;

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ** here customerID 6 will be null beacause there is no data for customerID 6 in the customers table**

# %%
Q2.

select c.customerID, c.customername, c.city, o.orderID, o.orderdate, o.amount
from customers c
left join orders o
on c.customerID = o.customerID;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Q3.

select o.orderID, o.customerID, o.orderdate, o.amount, c.customername, c.city
from orders o
left join customers c
on o.customerID = c.customerID;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Q4.

select
c.customerid,
c.customerName,
o.orderID,
o.orderdate,
o.amount
from customers c
left join orders o
on c.customerID = o.customerID

union

select
c.customerID,
c.customername,
o.orderID,
o.orderdate,
o.amount
from customers c
right join orders o
on c.customerID = o.customerID;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Q5.

SELECT
    c.CustomerID,
    c.CustomerName
FROM Customers c
LEFT JOIN Orders o
ON c.CustomerID = o.CustomerID
WHERE o.CustomerID IS NULL;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Q6.

SELECT DISTINCT
    c.CustomerID,
    c.CustomerName
FROM Customers c
JOIN Payments p
    ON c.CustomerID = p.CustomerID
LEFT JOIN Orders o
    ON c.CustomerID = o.CustomerID
WHERE o.CustomerID IS NULL;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Q7.

SELECT
    c.CustomerID,
    c.CustomerName,
    o.OrderID,
    o.OrderDate,
    o.Amount
FROM Customers c
CROSS JOIN Orders o ;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Q8.

select
c.customerID,
c.customername,
o.orderID,
o.Amount as orderAmount,
p.paymentID,
p.Amount as paymentAmount
from customers c
left join orders o
on c.customerID = o.customerID
left join payments p
on c.customerID = p.customerID;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Q9.

select distinct
c.customerID,
c.customername
from customers c
inner join orders o
on c.customerID = o.customerID
inner join payments p
on c.customerID = p.customerID;

# %% [markdown]
# ![image.png](data:image/png;base64,...)
